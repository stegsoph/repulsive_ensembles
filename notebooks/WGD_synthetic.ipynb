# %% [markdown]
# # Repulsive deep ensembles are Bayesian

# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:100% !important; }</style>

# %%
import math
import numpy as np
import torch
import torch.autograd as autograd
import torch.optim as optim
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)
import os 
os.chdir('/home/TUG/steger-tug/code/BNNs/repulsive_ensembles/')
from utils.SSGE_squeeze import SpectralSteinEstimator

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# %config InlineBackend.figure_format = 'retina'
sns.set(style="darkgrid")
matplotlib.rcParams['figure.dpi']= 100
sns.set(style="white")

# %% [markdown]
# ## RBF Kernel
#
# The RBF kernel is defined as the squared exponential distance between the two vectors. The bandwidth of the kernel is reffered to as  $h$.
#
# $$
# k_{RBF}(\mathbf{x}, \mathbf{x}^\prime) = \exp \bigg( {-\frac{1}{h}||\mathbf{x}-\mathbf{x}^\prime||^2} \bigg)
# $$

# %%
class RBF(torch.nn.Module):
    def __init__(self, h=None):
        super(RBF, self).__init__()

        self.h = h
        
    def median(self,tensor):
        tensor = tensor.flatten().sort()[0]
        length = tensor.shape[0]

        if length % 2 == 0:
            szh = length // 2
            kth = [szh - 1, szh]
        else:
            kth = [(length - 1) // 2]
        return tensor[kth].mean()


    def forward(self, X, Y):
        XX = X.matmul(X.t())
        XY = X.matmul(Y.t())
        YY = Y.matmul(Y.t())

        dnorm2 = -2 * XY + XX.diag().unsqueeze(1) + YY.diag().unsqueeze(0)
        
        
        # Apply the median heuristic (PyTorch does not give true median)
        if self.h is None:
            h = self.median(dnorm2.detach()) / (2*torch.tensor(math.log(X.size(0))))
        else:
            h = self.h**2

        gamma = 1.0 / (2*h)
        K_XY = (-gamma * dnorm2).exp()

        return K_XY

# %% [markdown]
# ## Performing Wasserstein Gradient Descent or Stein Variational Gradient Descent  corresponds to simulate the following discretized ODE for each particle $x_i$ in the system.

# %% [markdown]
# ### Stein Variational Gradient Descent (SVGD)
#
# $$
#      x^{t+1}_i = x^{t}_i + \epsilon_t \bigg( \sum_{j=1}^n k(x_i^t,x_j^t) \nabla_{x_i^t} \log p(x_i^t) + \sum_{j=1}^n\nabla_{x_j^t} k(x_j^t,x_i^t) \bigg)
# $$
# ### Wasserstein Gradient Descent (WGD) with KDE
# $$
#     x^{t+1}_i = x^{t}_i + \epsilon_t \bigg( \nabla \log p(x^{t}_i) -  \frac{\sum_{j=1}^n\nabla_{x_i^t} k(x_i^t,x_j^t)}{\sum_{j=1}^n k(x_i^t,x_j^t)}  \bigg) \, ,
# $$
# ###  Wasserstein Gradient Descent with SGE
# $$
#  x^{t+1}_i = x^{t}_i + \epsilon_t \bigg( \nabla \log \pi(x^{t}_i) +\sum_{j=1}^n (K + \eta \mathbb{I})^{-1}_{ij} \sum_{k=1}^n  \nabla_{x^t_k} k(x^t_k,x^t_j) \bigg)
# $$
# ###  Wasserstein Gradient Descent with SSGE
#
# $$
# x_{t+1}^i = x_{t}^i + \epsilon_t \bigg( \nabla \log \pi(x_{t}^i) +\sum_{j=1}^J  \frac{1}{\lambda_j^2 }   \sum_{m=1}^n  \sum_{k=1}^n u_{jk} \nabla_{x_m} k(x_m^t,x_k^t) \cdot \sum_{l=1}^n u_{jl}k(x_i^t,x^t_l)  \bigg)
# $$

# %%
class SVGD:
    def __init__(self, P, K, optimizer):
        self.P = P
        self.K = K
        self.optim = optimizer

    def phi(self, X):
        X = X.detach().requires_grad_(True)

        log_prob = self.P.log_prob(X)
        score_func = autograd.grad(log_prob.sum(), X)[0]

        K_XX = self.K(X, X.detach())
        grad_K = -autograd.grad(K_XX.sum(), X)[0]

        phi = (K_XX.detach().matmul(score_func) + grad_K) / X.size(0)
        #phi = score_func

        return phi

    def step(self, X):
        self.optim.zero_grad()
        X.grad = -self.phi(X)
        self.optim.step()

# %%
class WGD:
    def __init__(self, P, K, optimizer):
        self.P = P
        self.K = K
        self.optim = optimizer

    def phi(self, X):
        X = X.detach().requires_grad_(True)

        log_prob = self.P.log_prob(X)
        score_func = autograd.grad(log_prob.sum(), X)[0]

        K_XX = self.K(X, X.detach())
        grad_K = autograd.grad(K_XX.sum(), X)[0] 

        phi = ((score_func)-grad_K/ (K_XX.sum(1,keepdim = True))) 
        return phi, score_func, grad_K/ (K_XX.sum(1,keepdim = True))

    def step(self, X):
        self.optim.zero_grad()
        up,att,rep = self.phi(X)
        X.grad = -up
        self.optim.step()
        return att, rep

# %%
class ssge_WGD:
    def __init__(self, P, K, optimizer, grad_estim):
        self.P = P
        self.K = K
        self.optim = optimizer
        self.pge = grad_estim


    def phi(self, X):
        X = X.detach().requires_grad_(True)

        log_prob = self.P.log_prob(X)
        score_func = autograd.grad(log_prob.sum(), X)[0]

        #K_XX = self.K(X, X.detach())
        #grad_K = autograd.grad(K_XX.sum(), X)[0] 
        
        grad_density = self.pge.compute_score_gradients(X, X)  # .mean(0)

        phi = (score_func-grad_density) 
        return phi

    def step(self, X):
        self.optim.zero_grad()
        X.grad = -self.phi(X)
        self.optim.step()

# %%
class sge_WGD:
    def __init__(self, P, K, optimizer):
        self.P = P
        self.K = K
        self.optim = optimizer


    def phi(self, X):
        X = X.detach().requires_grad_(True)

        log_prob = self.P.log_prob(X)
        score_func = autograd.grad(log_prob.sum(), X)[0]

        #K_XX = self.K(X, X.detach())
        #grad_K = autograd.grad(K_XX.sum(), X)[0] 
        
        eta = 0.01
        K_X = self.K(X, X.detach())
        grad_K = autograd.grad(K_X.sum(), X)[0] 
        K_ = K_X+eta*torch.eye(K_X.shape[0]).to(device)  
        grad_density = torch.linalg.solve(K_,grad_K)
        
        phi = (score_func-grad_density) 
        return phi

    def step(self, X):
        self.optim.zero_grad()
        X.grad = -self.phi(X)
        self.optim.step()

# %%
class MAP:
    def __init__(self, P, K, optimizer):
        self.P = P
        self.K = K
        self.optim = optimizer

    def phi(self, X):
        X = X.detach().requires_grad_(True)

        log_prob = self.P.log_prob(X)
        score_func = autograd.grad(log_prob.sum(), X)[0]

        phi = score_func
        #phi = score_func

        return phi

    def step(self, X):
        self.optim.zero_grad()
        X.grad = -self.phi(X)
        self.optim.step()

# %% [markdown]
# # Experiments
#
# ## Unimodal Gaussian
#
# We will first run the different methods to learn a Multivariate Gaussian Distribution.

# %%
def plot_density_particles(samples, particles, name):
    
    particles_np = particles.detach().cpu().numpy()
    
    g = sns.JointGrid(x=samples[:,0],y=samples[:,1], height=4)
    sns.scatterplot(x=particles_np[:,0], y=particles_np[:,1], color='orange', 
                    ax=g.ax_joint, alpha=1.0, s=50, zorder=1, edgecolor='black', label=name)
    
    sns.kdeplot(x=samples[:,0],y=samples[:,1] ,cmap='Blues', fill=True, 
                levels=15, ax=g.ax_joint, zorder = 0)
    
    sns.kdeplot(x=samples[:, 0],  color='r', ax=g.ax_marg_x, label='true')
    sns.kdeplot(y=samples[:, 1],  color='r', ax=g.ax_marg_y)
    sns.kdeplot(x=particles_np[:, 0],  color='b', ax=g.ax_marg_x, label=name)
    sns.kdeplot(y=particles_np[:, 1],  color='b', ax=g.ax_marg_y)
    
    g.ax_marg_x.axis('off')
    g.ax_marg_y.axis('off')
    g.ax_joint.legend(loc='upper left', framealpha=0)
    g.ax_marg_x.legend(loc='upper right',bbox_to_anchor=(1.2, 1.3), framealpha=0)
    
    # return g

# %%
gauss = torch.distributions.MultivariateNormal(
        torch.Tensor([-0.68,0.80]).to(device),
        covariance_matrix=5 * torch.Tensor([[0.22,0.16],[0.16,0.67]]).to(device)
        )


p_0 = torch.distributions.multivariate_normal.MultivariateNormal(
        torch.tensor([-1, 5],dtype=torch.float),
        0.5*torch.eye(2)
        )

n = 100
X_init = (3 * torch.randn(n, *gauss.event_shape)).to(device)
X_init = p_0.sample(torch.Size([n])).to(device)

# sample_test = gauss.sample(torch.Size([100])).cpu().numpy()

# X_init_np = X_init.detach().cpu().numpy()
# sns.kdeplot(x=X_init_np[:,0],y=X_init_np[:,1], 
#             cmap='Blues', fill=True, levels=15)
# sns.scatterplot(x=X_init_np[:,0],y=X_init_np[:,1])

# %%
samples = gauss.sample(torch.Size([4000])).detach().cpu().numpy() #.to(device)

# %%
K = RBF(0.5)
lr = 1e-1

# %%
X_SVGD = X_init.clone()
X_WGD = X_init.clone()
X_MAP = X_init.clone()
X_sge_WGD = X_init.clone()
X_ssge_WGD = X_init.clone()

svgd = SVGD(gauss, K, optim.Adam([X_SVGD], lr=lr))
wgd = WGD(gauss, K, optim.Adam([X_WGD], lr=lr))
pmap = MAP(gauss, K, optim.Adam([X_MAP], lr=lr))

ssge_k = RBF()
#K = real_PP_K(exp = True)
ssge = SpectralSteinEstimator(0.01,None,ssge_k, device = device)
X_ssge_WGD = X_init.clone()
ssege_wgd = ssge_WGD(gauss, K, optim.Adam([X_ssge_WGD], lr=lr),ssge)
sge_wgd = sge_WGD(gauss, K, optim.Adam([X_sge_WGD], lr=lr))

att_l = []
rep_l = []
t_steps = 10000
for i in tqdm(range(t_steps),position=0, leave=True):       
    svgd.step(X_SVGD)
    att,rep = wgd.step(X_WGD)
    att_l.append(np.linalg.norm(att.detach().cpu().numpy()))
    rep_l.append(np.linalg.norm(rep.detach().cpu().numpy()))
    pmap.step(X_MAP)
    ssege_wgd.step(X_ssge_WGD)
    sge_wgd.step(X_sge_WGD)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]/home/TUG/steger-tug/code/BNNs/repulsive_ensembles/utils/SSGE_squeeze.py:58: UserWarning: torch.eig is deprecated in favor of torch.linalg.eig and will be removed in a future PyTorch release.
# torch.linalg.eig returns complex tensors of dtype cfloat or cdouble rather than real tensors mimicking complex tensors.
# L, _ = torch.eig(A)
# should be replaced with
# L_complex = torch.linalg.eigvals(A)
# and
# L, V = torch.eig(A, eigenvectors=True)
# should be replaced with
# L_complex, V_complex = torch.linalg.eig(A) (Triggered internally at  /pytorch/aten/src/ATen/native/BatchLinearAlgebra.cpp:2897.)
#   eigen_vals, eigen_vecs = torch.eig(Kxx eigenvectors=True)
#  14%|█▍        | 1438/10000 [00:58<05:47, 24.62it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 23
#      21 for i in tqdm(range(t_steps),position=0, leave=True):
#      22     svgd.step(X_SVGD)
# ---> 23     att,rep = wgd.step(X_WGD)
#      24     att_l.append(np.linalg.norm(att.detach().cpu().numpy()))
#      25     rep_l.append(np.linalg.norm(rep.detach().cpu().numpy()))
#
# Cell In[9], line 21, in WGD.step(self, X)
#      19 def step(self, X):
#      20     self.optim.zero_grad()
# ---> 21     up,att,rep = self.phi(X)
#      22     X.grad = -up
#      23     self.optim.step()
#
# Cell In[9], line 14, in WGD.phi(self, X)
#      11 score_func = autograd.grad(log_prob.sum(), X)[0]
#      13 K_XX = self.K(X, X.detach())
# ---> 14 grad_K = autograd.grad(K_XX.sum(), X)[0]
#      16 phi = ((score_func)-grad_K/ (K_XX.sum(1,keepdim = True)))
#      17 return phi, score_func, grad_K/ (K_XX.sum(1,keepdim = True))
#
# KeyboardInterrupt:

# %%
plot_density_particles(samples,X_init,'Init')
plot_density_particles(samples,X_SVGD,'SVGD')
plot_density_particles(samples,X_WGD,'kde-WGD')
plot_density_particles(samples,X_MAP,'MAP')
plot_density_particles(samples,X_ssge_WGD, 'SSGE-WGD')
plot_density_particles(samples,X_sge_WGD,'SGE-WGD')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 6
#       4 plot_density_particles(samples,X_MAP,'MAP')
#       5 plot_density_particles(samples,X_ssge_WGD, 'SSGE-WGD')
# ----> 6 plot_density_particles(samples,X_sge_WGD,'SGE-WGD')
#
# Cell In[23], line 9, in plot_density_particles(samples, particles, name)
#       5 g = sns.JointGrid(x=samples[:,0],y=samples[:,1], height=4)
#       6 sns.scatterplot(x=particles_np[:,0], y=particles_np[:,1], color='orange',
#       7                 ax=g.ax_joint, alpha=1.0, s=50, zorder=1, edgecolor='black', label=name)
# ----> 9 sns.kdeplot(x=samples[:,0],y=samples[:,1] ,cmap='Blues', fill=True,
#      10             levels=15, ax=g.ax_joint, zorder = 0)
#      12 sns.kdeplot(x=samples[:, 0],  color='r', ax=g.ax_marg_x, label='true')
#      13 sns.kdeplot(y=samples[:, 1],  color='r', ax=g.ax_marg_y)
#
# File ~/miniconda3/envs/pip-torch/lib/python3.9/site-packages/seaborn/distributions.py:1731, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1717     p.plot_univariate_density(
#    1718         multiple=multiple,
#    1719         common_norm=common_norm,
#    (...)
#    1726         **plot_kws,
#    1727     )
#    1729 else:
# -> 1731     p.plot_bivariate_density(
#    1732         common_norm=common_norm,
#    1733         fill=fill,
#    1734         levels=levels,
#    1735         thresh=thresh,
#    1736         legend=legend,
#    1737         color=color,
#    1738         warn_singular=warn_singular,
#    1739         cbar=cbar,
#    1740         cbar_ax=cbar_ax,
#    1741         cbar_kws=cbar_kws,
#    1742         estimate_kws=estimate_kws,
#    1743         **kwargs,
#    1744     )
#    1746 return ax
#
# File ~/miniconda3/envs/pip-torch/lib/python3.9/site-packages/seaborn/distributions.py:1081, in _DistributionPlotter.plot_bivariate_density(self, common_norm, fill, levels, thresh, color, legend, cbar, warn_singular, cbar_ax, cbar_kws, estimate_kws, **contour_kws)
#    1079 try:
#    1080     if not singular:
# -> 1081         density, support = estimator(*observations, weights=weights)
#    1082 except np.linalg.LinAlgError:
#    1083     # Testing for 0 variance doesn't catch all cases where scipy raises,
#    1084     # but we can also get a ValueError, so we need this convoluted approach
#    1085     singular = True
#
# File ~/miniconda3/envs/pip-torch/lib/python3.9/site-packages/seaborn/_statistics.py:194, in KDE.__call__(self, x1, x2, weights)
#     192     return self._eval_univariate(x1, weights)
#     193 else:
# --> 194     return self._eval_bivariate(x1, x2, weights)
#
# File ~/miniconda3/envs/pip-torch/lib/python3.9/site-packages/seaborn/_statistics.py:185, in KDE._eval_bivariate(self, x1, x2, weights)
#     182 else:
#     184     xx1, xx2 = np.meshgrid(*support)
# --> 185     density = kde([xx1.ravel(), xx2.ravel()]).reshape(xx1.shape)
#     187 return density, support
#
# File ~/miniconda3/envs/pip-torch/lib/python3.9/site-packages/scipy/stats/_kde.py:268, in gaussian_kde.evaluate(self, points)
#     265         raise ValueError(msg)
#     267 output_dtype, spec = _get_output_dtype(self.covariance, points)
# --> 268 result = gaussian_kernel_estimate[spec](
#     269     self.dataset.T, self.weights[:, None],
#     270     points.T, self.cho_cov, output_dtype)
#     272 return result[:, 0]
#
# KeyboardInterrupt:

# %% [markdown]
# # Neal's funnel experiments

# %%
import torch.distributions as dist
from torch.distributions import constraints
from torch.distributions.utils import _standard_normal

class NealsFunnel(dist.Distribution):
    """
    Neal's funnel.
    p(x,y) = N(y|0,3) N(x|0,exp(y/2))
    """

    support = constraints.real

    def __init__(self, validate_args=None):
        d = 2
        batch_shape, event_shape = torch.Size([]), (d,)
        super(NealsFunnel, self).__init__(
            batch_shape, event_shape, validate_args=validate_args
        )

    def rsample(self, sample_shape=None,device=torch.device("cpu")):
        if not sample_shape:
            sample_shape = torch.Size()
        eps = _standard_normal(
            (sample_shape[0], 2), dtype=torch.float, device=device
        )
        z = torch.zeros(eps.shape)
        z[..., 1] = torch.tensor(3.0) * eps[..., 1]
        z[..., 0] = torch.exp(z[..., 1] / 2.0) * eps[..., 0]
        return z

    def log_prob(self, value):
        if self._validate_args:
            self._validate_sample(value)
        x = value[..., 0]
        y = value[..., 1]

        log_prob = dist.Normal(0, 3).log_prob(y)
        log_prob += dist.Normal(0, torch.exp(y / 2)).log_prob(x)

        return log_prob

# Create Neal's Funnel in 2D
target_dist = NealsFunnel()
#target_dist = torch.distributions.Normal(torch.zeros(input_dim)+5, torch.ones(input_dim)*0.5)
y_target = target_dist.rsample((1000,))
# Out:
# /home/TUG/steger-tug/miniconda3/envs/pip-torch/lib/python3.9/site-packages/torch/distributions/distribution.py:44: UserWarning: <class '__main__.NealsFunnel'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(f'{self.__class__} does not define `arg_constraints`. ' +

# %%
n_pts = 300
range_lim = 4

n = 500

X_init = (5 * torch.randn(n, *torch.Size([2]))).to(device)
test_every = 1
X_SVGD = X_init.clone()
X_WGD = X_init.clone()
X_MAP = X_init.clone()
X_ssge_WGD = X_init.clone()
X_sge_WGD = X_init.clone()


K = RBF()

h = 0.5

p =  NealsFunnel()

svgd = SVGD(p, K, optim.Adam([X_SVGD], lr=1e-1))
wgd = WGD(p, K, optim.Adam([X_WGD], lr=1e-1))
pmap = MAP(p, K, optim.Adam([X_MAP], lr=1e-1))
ssege_wgd = ssge_WGD(p, K, optim.Adam([X_ssge_WGD], lr=1e-1),ssge)
sge_wgd = sge_WGD(p, K, optim.Adam([X_sge_WGD], lr=1e-1))

t_steps = 1000 #5000
mmd_ssge_l =[]
mmd_sge_l =[]
mmd_svgd_l =[]
mmd_kde_l =[]
mmd_map_l =[]
for i in tqdm(range(t_steps),position=0, leave=True):       
    svgd.step(X_SVGD)
    wgd.step(X_WGD)
    pmap.step(X_MAP)
    ssege_wgd.step(X_ssge_WGD)
    sge_wgd.step(X_sge_WGD)
    # if not i%test_every:
    #     mmd_ssge =(MMD(y_target,X_ssge_WGD.clone(),h=h,biased = False).item())
    #     mmd_sge = (MMD(y_target,X_sge_WGD.clone(),h=h,biased = False).item())
    #     mmd_svgd = (MMD(y_target,X_SVGD.clone(),h=h,biased = False).item())
    #     mmd_kde = (MMD(y_target,X_WGD.clone(),h=h,biased = False).item())
    #     mmd_map = (MMD(y_target,X_MAP.clone(),h=h,biased = False).item())

    #     mmd_ssge_l.append(mmd_ssge)
    #     mmd_sge_l.append(mmd_sge)
    #     mmd_svgd_l.append(mmd_svgd)
    #     mmd_kde_l.append(mmd_kde)
    #     mmd_map_l.append(mmd_map)
# Out:
# 100%|██████████| 5000/5000 [30:08<00:00,  2.76it/s]

# %%
fig, axs = plt.subplots(1, 4, figsize=(15,6))

y_target_np = y_target.numpy()
X_SVGD_np = X_SVGD.cpu().numpy()
X_WGD_np = X_WGD.cpu().numpy()
X_ssge_WGD_np = X_ssge_WGD.cpu().numpy()
X_sge_WGD_np = X_sge_WGD.cpu().numpy()

sns.scatterplot(x=y_target_np[:,0], y=y_target_np[:,1], 
                color ='royalblue', alpha = 0.6,s = 30, ax = axs[0], zorder = 1, edgecolor='black', label = 'Target')
sns.scatterplot(x=X_SVGD_np[:,0], y=X_SVGD_np[:,1], 
                color ='orange', alpha = 0.9,s = 30, zorder = 1, ax = axs[0], edgecolor='black',label ='SVGD')

axs[0].set_title('Funnel SVGD h=median')
axs[0].set_xlim([-12,12])

sns.scatterplot(x=y_target_np[:,0], y=y_target_np[:,1], 
                color ='royalblue', alpha = 0.6,s = 30, ax = axs[1], zorder = 1, edgecolor='black', label = 'Target')
sns.scatterplot(x=X_WGD_np[:,0], y=X_WGD_np[:,1], 
                color ='orange', alpha = 0.9,s = 30, zorder = 1,ax = axs[1], edgecolor='black', label = 'kde-WGD')
axs[1].set_title('Funnel WGD h=median')
axs[1].set_xlim([-12,12])
axs[1].set_yticks([])

sns.scatterplot(x=y_target_np[:,0], y=y_target_np[:,1], 
                color ='royalblue', alpha = 0.6,s = 30, ax = axs[2], zorder = 1, edgecolor='black', label = 'Target')
sns.scatterplot(x=X_ssge_WGD_np[:,0], y=X_ssge_WGD_np[:,1], 
                color ='orange', alpha = 0.9,s = 30, zorder = 1,ax = axs[2], edgecolor='black', label = 'SSGE-WGD')
axs[2].set_title('Funnel ssge WGD h=median')
axs[2].set_xlim([-12,12])
axs[2].set_yticks([])

sns.scatterplot(x=y_target_np[:,0], y=y_target_np[:,1], 
                color ='royalblue', alpha = 0.6,s = 30, ax = axs[3], zorder = 1, edgecolor='black', label = 'Target')
sns.scatterplot(x=X_sge_WGD_np[:,0], y=X_sge_WGD_np[:,1], 
                color ='orange', alpha = 0.9,s = 30, zorder = 1,ax = axs[3], edgecolor='black', label = 'SGE-WGD')
axs[3].set_title('Funnel ssge WGD h=median')
axs[3].set_xlim([-12,12])
axs[3].set_yticks([])

plt.show()
